# %% [markdown]
# Early computers were designed to perform a limited set of tasks, such as calculations and data processing. They were not designed to handle the complexity of human language, and their ability to understand and generate text was limited. They were 8 bits in size where we can  use only 256.

# %% [markdown]
# `Python official unicode guide`

# %% [markdown]
# `1.Creating strings`

# %%
a='arsal'
b="arslan"
c="""shahzad"""
d=str('gondal')

# %%
print("it's is a good day")
# Out:
# it's is a good day

# %% [markdown]
# `String Indexing`

# %%
a='arslan shahzad gondal'
a[0]
# Out:
# 'a'

# %%
a[8]
# Out:
# 'h'

# %% [markdown]
# `String Slicing`

# %%
print(a[0:6])
print(a[0:])
print(a[0:6:2])
# Out:
# arslan
# arslan shahzad gondal
# asa

# %%
print(a[::-1])
# Out:
# ladnog dazhahs nalsra

# %%
print(a[-1])
print(a[-2:])
# Out:
# l
# al

# %%
a[0]='A' # string is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a[0]='A' # string is immutable
#
# TypeError: 'str' object does not support item assignment

# %%
del b # works for entire string nor on a single value

# %%
print('Arslan'+' ' + 'Shahzad')
# Out:
# Arslan Shahzad

# %%
print('Arslan '*3)
# Out:
# Arslan Arslan Arslan

# %%
print('Arslan' in 'Arslan Shahzad')
# Out:
# True

# %%
'arslan'=='shahzad'
# Out:
# False

# %%
'arslan'>'shahzad' # lexicographically comparision
# Out:
# False

# %%
'shahzad'>'arslan'
# Out:
# True

# %%
a='arslan'
b='shahzad'
c=a+b
print(c)
d=a*3
print(d)
# Out:
# arslanshahzad
# arslanarslanarslan

# %%
'Arslan'>'arslan' # lexicographically comparision the smaller character comes first in the alphabet table
# Out:
# False

# %%
'hello' and 'world'
# Out:
# 'world'

# %%
'hellow' or 'world'
# Out:
# 'hellow'

# %%
'' and 'world'
# Out:
# ''

# %%
'' or 'world'
# Out:
# 'world'

# %%
not ''
# Out:
# True

# %%
not 'aus'
# Out:
# False

# %%
for i in 'arslan':
    print('shahzad')
# Out:
# shahzad
# shahzad
# shahzad
# shahzad
# shahzad
# shahzad

# %%
# common functions for lists,strings,tuples and sets
len('arslan') # length of the string
max('arslan') # max based on ascii value
min('arslan') # min based on ascii value
sorted('arslan') # sorted based on ascii value
# Out:
# ['a', 'a', 'l', 'n', 'r', 's']

# %%
a='arslan shahzad gondal'
a.upper()
a.lower()
a.title()
a.swapcase()
# Out:
# 'ARSLAN SHAHZAD GONDAL'

# %%
a.count('a') # count the number of a in the string
a.find('a') # find the index of the first a
a.rfind('a') # find the index of the last a 
a.index('a') # find the index of the first a
# Out:
# 0

# %%
a.replace('a','A') # replace all a with A
# Out:
# 'ArslAn shAhzAd gondAl'

# %%
a.endswith('al') # check if the string ends with al
a.startswith('a') # check if the string starts with a
# Out:
# True

# %%
a.strip()
# Out:
# 'arslan shahzad gondal'

# %%
a.split()
# Out:
# ['arslan', 'shahzad', 'gondal']

# %%
x='Hello Arslan Shahzad'
'gondal shb {}'.format(x)
# Out:
# 'gondal shb Hello Arslan Shahzad'

# %%
a='arslan1235'
a.isalnum()
# Out:
# True

# %%
a.isalpha()
# Out:
# False

# %%
a.isdigit()
# Out:
# False

# %%
a.isidentifier()
# Out:
# True

# %%
ab-ba.isidentifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 ab-ba.isidentifier()
#
# NameError: name 'ab' is not defined

# %%
a.split('a')
# Out:
# ['', 'rsl', 'n1235']

# %%
a.join('a')
# Out:
# 'a'

# %%
''.join('arslan'+'shahzad')
# Out:
# 'arslanshahzad'

# %%
'-'.join('arslan')
# Out:
# 'a-r-s-l-a-n'

# %%
a='arslan shahzad gondal'
a.replace('arslan','Muhammad')
# Out:
# 'Muhammad shahzad gondal'

# %%
counter=1
for i in a:
    counter+=1
print(counter)
# Out:
# 22
